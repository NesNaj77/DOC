# %%
import pandas as pd

# %%
S=pd.Series(["YAS","RAY","DADI"])
print(S)
# Out:
# 0     YAS
# 1     RAY
# 2    DADI
# dtype: object

# %%
filles=(["YAS","RAY","DADI"])
Indextype = ["Index1","Index2","Index3"]
S1=pd.Series(filles,index=Indextype)
print(S1)
# Out:
# Index1     YAS
# Index2     RAY
# Index3    DADI
# dtype: object

# %%
X=pd.Series([10,20,30],index=Indextype)
Y=pd.Series([40,50,60], index=Indextype)
print(X+Y)
# Out:
# Index1    50
# Index2    70
# Index3    90
# dtype: int64

# %%
df=pd.read_csv("cardata.csv") #créer dataframe à partir du csv
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head(10) # sélectionner les 10 premières lignes
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.tail(10) #sélectionner les 10 dernières lignes
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# ...

# %%
df.drop("Present_Price",axis=1) #supprimer une colonne (axis=1)/ axis = 0 c'est ligne
# Out:
#     Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz  2014           3.35       27000    Petrol      Dealer
# 1        sx4  2013           4.75       43000    Diesel      Dealer
# 2       ciaz  2017           7.25        6900    Petrol      Dealer
# 3    wagon r  2011           2.85        5200    Petrol      Dealer
# 4      swift  2014           4.60       42450    Diesel      Dealer
# ..       ...   ...            ...         ...       ...         ...
# 296     city  2016           9.50       33988    Diesel      Dealer
# 297     brio  2015           4.00       60000    Petrol      Dealer
# 298     city  2009           3.35       87934    Petrol      Dealer
# 299     city  2017          11.50        9000    Diesel      Dealer
# 300     brio  2016           5.30        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# ...

# %%
df["Selling_Price"].describe() #Décrire la data
# Out:
# count    301.000000
# mean       4.661296
# std        5.082812
# min        0.100000
# 25%        0.900000
# 50%        3.600000
# 75%        6.000000
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
df[0:5] #sélectionner les lignes
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df[["Car_Name","Fuel_Type"]] #sélectionner les colonnes nommées
# Out:
#     Car_Name Fuel_Type
# 0       ritz    Petrol
# 1        sx4    Diesel
# 2       ciaz    Petrol
# 3    wagon r    Petrol
# 4      swift    Diesel
# ..       ...       ...
# 296     city    Diesel
# 297     brio    Petrol
# 298     city    Petrol
# 299     city    Diesel
# 300     brio    Petrol
#
# [301 rows x 2 columns]

# %%
df.iloc[0:3,2:5] # Selectionner les 3 premières lignes et les colonnes allant de 3 à 5
# Out:
#    Selling_Price  Present_Price  Kms_Driven
# 0           3.35           5.59       27000
# 1           4.75           9.54       43000
# 2           7.25           9.85        6900

# %%
df.loc[100:150] #sélectionner les lignes de 100 à 150
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 100  Royal Enfield Thunder 500  2016           1.75          1.900
# 101         UM Renegade Mojave  2017           1.70          1.820
# 102                  KTM RC200  2017           1.65          1.780
# 103          Bajaj Dominar 400  2017           1.45          1.600
# 104  Royal Enfield Classic 350  2017           1.35          1.470
# 105                  KTM RC390  2015           1.35          2.370
# 106             Hyosung GT250R  2014           1.35          3.450
# 107  Royal Enfield Thunder 350  2013           1.25          1.500
# 108  Royal Enfield Thunder 350  2016           1.20          1.500
# 109  Royal Enfield Classic 350  2017           1.20          1.470
# 110                  KTM RC200  2016           1.20          1.780
# 111  Royal Enfield Thunder 350  2016           1.15          1.500
# 112              KTM 390 Duke   2014           1.15          2.400
# ...

# %%
df.loc[146:150,"Car_Name":"Selling_Price"]
# Out:
#                Car_Name  Year  Selling_Price
# 146        Hero Extreme  2014           0.55
# 147   Yamaha FZ S V 2.0  2015           0.55
# 148  Bajaj Pulsar 220 F  2010           0.52
# 149  Bajaj Pulsar 220 F  2016           0.51
# 150  TVS Apache RTR 180  2011           0.50

# %%
df=df.set_index("Car_Name")
df
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# ...        ...            ...            ...         ...       ...
# city      2016           9.50          11.60       33988    Diesel
# brio      2015           4.00           5.90       60000    Petrol
# city      2009           3.35          11.00       87934    Petrol
# city      2017          11.50          12.50        9000    Diesel
# brio      2016           5.30           5.90        5464    Petrol
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# sx4           Dealer       Manual      0
# ...

# %%
df[df["Kms_Driven"]>5000]
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# ...        ...            ...            ...         ...       ...
# city      2016           9.50          11.60       33988    Diesel
# brio      2015           4.00           5.90       60000    Petrol
# city      2009           3.35          11.00       87934    Petrol
# city      2017          11.50          12.50        9000    Diesel
# brio      2016           5.30           5.90        5464    Petrol
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# sx4           Dealer       Manual      0
# ...

# %%
df["Kms_Driven"].describe ()
# Out:
# count       301.000000
# mean      36947.205980
# std       38886.883882
# min         500.000000
# 25%       15000.000000
# 50%       32000.000000
# 75%       48767.000000
# max      500000.000000
# Name: Kms_Driven, dtype: float64

# %%
df[df]
